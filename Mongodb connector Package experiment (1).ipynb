# %% [markdown]
# ### Lets first install the package that we created and released in pipy repository

# %%
pip install mongodb-database-automate==0.0.7
# Out:
# ...
#   Obtaining dependency information for mongodb-database-automate==0.0.7 from https://files.pythonhosted.org/packages/13/d1/49a13717f91f86df81174c8cc022d1ce163640b479fdb4a21c045578c8de/mongodb_database_automate-0.0.7-py3-none-any.whl.metadata
# ...
#   Attempting uninstall: mongodb-database-automate
#     Found existing installation: MongoDB_database_Automate 0.0.5
#     Uninstalling MongoDB_database_Automate-0.0.5:
#       Successfully uninstalled MongoDB_database_Automate-0.0.5
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip list
# Out:
# Package                       Version         Editable project location
# ----------------------------- --------------- -------------------------------------------------------------------------------------
# absl-py                       2.0.0
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aiohttp-retry                 2.8.3
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# alembic                       1.13.0
# amqp                          5.2.0
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.0
# anaconda-project              0.11.1
# antlr4-python3-runtime        4.9.3
# anyio                         3.5.0
# appdirs                       1.4.4
# ...

# %%
pip uninstall MongoDB_Database_Automation
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
from mongodb_database_automate import mongo_crud

# %%
# giving the values to the arguments that i have given to my constructor which is present inside my class mongo_operation
client_url="mongodb+srv://Mahendra:JTx5FZA7parBernO@cluster0.klmitxd.mongodb.net/?retryWrites=true&w=majority"
database_name="my_database" # here we can change our database name 
collection_name="my_collection" # here we can change the collection names if we want to store our records in different collections

# %%
mongo1=mongo_crud.mongo_operation(client_url,database_name,collection_name)

# %%
mongo1.insert_record({"name":"mahendra","designation":"datascientist","salary":"100k"},collection_name) # so by using the object name 
mongo1

# %%
# we successfully created the record in the mention database go and check in mongodb database
